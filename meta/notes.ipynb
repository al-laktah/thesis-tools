# %% [markdown]
# # Meeting 31.10.2024 Notes:
# - New Deadline 24.11.2024

# %% [markdown]
# ## What I have Done:

# %% [markdown]
# ### New BA Outline

# %% [markdown]
# ### LLM Scores

# %% [markdown]
# ### Meta
#
# 1. Short vs. Long Prompts
#     - Not just if shorter prompts preform better but also if it sticks to the instructions if there is less of them.
#
# 2. German vs. English Prompting
#
# 3. Instructability
#     - does it fail in a way that explictly goes against the prompt.
#     - for example providing explanations when the prompt says do not provide explnations
#     - related to 1
#
# 4. Failure Rate
#     - Failure here means running into constraints or not following instructions in prompt (translating, explnations, etc) and not failing on our report requirments.
#
# 5. Usefullness of Context
#     - Do Scores get better the more related context we include in the prompt
#     - and if it varies between models
#     - related to 1 and 3
#
# 6. Improvment
#     - Improvment based on our report requirments.

# %% [markdown]
# #### Diffchecker

# %% [markdown]
# #### Better Graphs

# %% [markdown]
# ## What i am working on:
# - Collecting and Reading Related Work
# - Writing
# - testing more prompts based on the Meta Goals
#     - english/german prompts
#     - testing prompts with more instructions/context
# - testing summariztion, to see if we can accomplish bullet points (Sven request)

# %% [markdown]
# ## What I need:
# - update on poll
